# %%
from genespectrakg import *
# %load_ext autoreload
# %autoreload 2
import pandas as pd
pd.set_option('display.max_columns', 500)
from genespectrakg.adapters.process_genespectra_input import *
human_classes = pd.read_csv(f"data/1TPM_lim/human_classes_subclass_1TPM_ensembl_name.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
human_processed = preprocess_genespectra_output(human_classes)

# %%
human_low = human_classes.loc[human_classes.spec_category == 'low cell type specificity'][['gene','spec_category', 'spec_score', 'dist_category', 'n_exp', 'mean_exp', 'max_exp', 'frac_exp', 'groups_expressed']]

# %%
human_low.head()
# Out:
#      gene              spec_category  spec_score               dist_category  \
# 0   A2MP1  low cell type specificity         0.0  expressed in less than 30%
# 4    ABAT  low cell type specificity         0.0       expressed in over 90%
# 5   ABCA5  low cell type specificity         0.0       expressed in over 90%
# 8   ABCG8  low cell type specificity         0.0       expressed in over 30%
# 10  ACAD9  low cell type specificity         0.0       expressed in over 90%
#
#     n_exp    mean_exp   max_exp    frac_exp  \
# 0       6    0.926376    2.9389   28.571429
# 4      21   92.913345  219.3110  100.000000
# 5      21  174.567690  346.9292  100.000000
# 8      15    1.423724    3.9225   71.428571
# 10     21   16.010462   35.8468  100.000000
#
#                                      groups_expressed
# 0   astrocyte of the cerebral cortex;cerebral cort...
# 4   L2/3 intratelencephalic projecting glutamaterg...
# 5   L2/3 intratelencephalic projecting glutamaterg...
# 8   L2/3 intratelencephalic projecting glutamaterg...
# 10  L2/3 intratelencephalic projecting glutamaterg...

# %%
human_low.columns = ['external_gene_name', 'specificity_category', 'specificity_score', 'distribution_catehory', 'n_expressed', 'mean_expression', 'max_expression', 'fraction_expressed', 'groups_expressed']

# %%
human_low
# Out:
#       external_gene_name       specificity_category  specificity_score  \
# 0                  A2MP1  low cell type specificity                0.0
# 4                   ABAT  low cell type specificity                0.0
# 5                  ABCA5  low cell type specificity                0.0
# 8                  ABCG8  low cell type specificity                0.0
# 10                 ACAD9  low cell type specificity                0.0
# ...                  ...                        ...                ...
# 18122            ZSCAN23  low cell type specificity                0.0
# 18123            ZSCAN29  low cell type specificity                0.0
# 18124            ZSCAN32  low cell type specificity                0.0
# 18125            ZSCAN5A  low cell type specificity                0.0
# 18127             ZSWIM7  low cell type specificity                0.0
#
#             distribution_catehory  n_expressed  mean_expression  \
# 0      expressed in less than 30%            6         0.926376
# 4           expressed in over 90%           21        92.913345
# 5           expressed in over 90%           21       174.567690
# 8           expressed in over 30%           15         1.423724
# 10          expressed in over 90%           21        16.010462
# ...                           ...          ...              ...
# 18122       expressed in over 90%           21        12.202442
# 18123       expressed in over 90%           21         3.505762
# 18124       expressed in over 90%           21         4.133062
# 18125  expressed in less than 30%            2         0.336129
# 18127       expressed in over 90%           21        19.304049
#
#        max_expression  fraction_expressed  \
# 0              2.9389           28.571429
# 4            219.3110          100.000000
# 5            346.9292          100.000000
# 8              3.9225           71.428571
# 10            35.8468          100.000000
# ...               ...                 ...
# 18122         19.6055          100.000000
# 18123         10.3791          100.000000
# 18124         13.5029          100.000000
# 18125          1.1922            9.523810
# 18127         41.8976          100.000000
#
#                                         groups_expressed
# 0      astrocyte of the cerebral cortex;cerebral cort...
# 4      L2/3 intratelencephalic projecting glutamaterg...
# 5      L2/3 intratelencephalic projecting glutamaterg...
# 8      L2/3 intratelencephalic projecting glutamaterg...
# 10     L2/3 intratelencephalic projecting glutamaterg...
# ...                                                  ...
# 18122  L2/3 intratelencephalic projecting glutamaterg...
# 18123  L2/3 intratelencephalic projecting glutamaterg...
# 18124  L2/3 intratelencephalic projecting glutamaterg...
# 18125   astrocyte of the cerebral cortex;microglial cell
# 18127  L2/3 intratelencephalic projecting glutamaterg...
#
# [9798 rows x 9 columns]

# %%
species_names_ids = {
    'hsapiens': '9606', 
    "mmulatta": '9544',
    'cjacchus': '9483', # marmoset
    'ptroglodytes': '9598', # chimpanzee
    'ggorilla': '9593', # western gorilla # seems to be 9595 in ncbi
}

# %%
cell_ontology = pd.read_csv("data/MTG_cell_type_to_ontology.csv", dtype=str)
cell_ontology = cell_ontology.drop(['subclass'], axis=1).drop_duplicates()

# %%
cell_ontology_no_ct = cell_ontology.drop(['cell_type_name', 'cell_ontology_id'], axis = 1).drop_duplicates()

# %%
species_name = 'hsapiens'
species_id = '9606'

# %%
cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]
# Out:
#              tissue_name uberon_tissue_id ncbi_txid species_scientific_name
# 0  middle temporal gyrus   UBERON:0002771      9606                hsapiens

# %%
human_low['tissue_name'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['tissue_name'].values[0]
human_low['uberon_tissue_id'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['uberon_tissue_id'].values[0]
human_low['ncbi_txid'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['ncbi_txid'].values[0]
human_low['species_scientific_name'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['species_scientific_name'].values[0]

# %%
human_low.head()
# Out:
#    external_gene_name       specificity_category  specificity_score  \
# 0               A2MP1  low cell type specificity                0.0
# 4                ABAT  low cell type specificity                0.0
# 5               ABCA5  low cell type specificity                0.0
# 8               ABCG8  low cell type specificity                0.0
# 10              ACAD9  low cell type specificity                0.0
#
#          distribution_catehory  n_expressed  mean_expression  max_expression  \
# 0   expressed in less than 30%            6         0.926376          2.9389
# 4        expressed in over 90%           21        92.913345        219.3110
# 5        expressed in over 90%           21       174.567690        346.9292
# 8        expressed in over 30%           15         1.423724          3.9225
# 10       expressed in over 90%           21        16.010462         35.8468
#
#     fraction_expressed                                   groups_expressed  \
# 0            28.571429  astrocyte of the cerebral cortex;cerebral cort...
# 4           100.000000  L2/3 intratelencephalic projecting glutamaterg...
# 5           100.000000  L2/3 intratelencephalic projecting glutamaterg...
# 8            71.428571  L2/3 intratelencephalic projecting glutamaterg...
# 10          100.000000  L2/3 intratelencephalic projecting glutamaterg...
#
#               tissue_name uberon_tissue_id ncbi_txid species_scientific_name
# 0   middle temporal gyrus   UBERON:0002771      9606                hsapiens
# 4   middle temporal gyrus   UBERON:0002771      9606                hsapiens
# 5   middle temporal gyrus   UBERON:0002771      9606                hsapiens
# 8   middle temporal gyrus   UBERON:0002771      9606                hsapiens
# 10  middle temporal gyrus   UBERON:0002771      9606                hsapiens

# %%
all_species_mapped = pd.read_csv("data/MTG_eggnog_ensembl_mapped_mammalia.csv", dtype=str)

# %%
species_tbl = all_species_mapped.loc[all_species_mapped.species_id == species_id]
species_tbl = species_tbl[['ensembl_gene_id', 'external_gene_name']]
species_classes_final = human_low.merge(species_tbl, left_on='external_gene_name', right_on='external_gene_name', how='left').dropna().reset_index(drop=True)
print(species_classes_final.shape)
# Out:
# (8766, 14)

# %%
species_classes_final
# Out:
#      external_gene_name       specificity_category  specificity_score  \
# 0                  ABAT  low cell type specificity                0.0
# 1                 ABCA5  low cell type specificity                0.0
# 2                 ABCG8  low cell type specificity                0.0
# 3                 ACAD9  low cell type specificity                0.0
# 4                 ACAT1  low cell type specificity                0.0
# ...                 ...                        ...                ...
# 8761            ZSCAN23  low cell type specificity                0.0
# 8762            ZSCAN29  low cell type specificity                0.0
# 8763            ZSCAN32  low cell type specificity                0.0
# 8764            ZSCAN5A  low cell type specificity                0.0
# 8765             ZSWIM7  low cell type specificity                0.0
#
#            distribution_catehory  n_expressed  mean_expression  \
# 0          expressed in over 90%           21        92.913345
# 1          expressed in over 90%           21       174.567690
# 2          expressed in over 30%           15         1.423724
# 3          expressed in over 90%           21        16.010462
# 4          expressed in over 90%           21        37.789974
# ...                          ...          ...              ...
# 8761       expressed in over 90%           21        12.202442
# 8762       expressed in over 90%           21         3.505762
# 8763       expressed in over 90%           21         4.133062
# 8764  expressed in less than 30%            2         0.336129
# 8765       expressed in over 90%           21        19.304049
#
#       max_expression  fraction_expressed  \
# 0           219.3110          100.000000
# 1           346.9292          100.000000
# 2             3.9225           71.428571
# 3            35.8468          100.000000
# 4            89.4445          100.000000
# ...              ...                 ...
# 8761         19.6055          100.000000
# 8762         10.3791          100.000000
# 8763         13.5029          100.000000
# 8764          1.1922            9.523810
# 8765         41.8976          100.000000
#
#                                        groups_expressed  \
# 0     L2/3 intratelencephalic projecting glutamaterg...
# 1     L2/3 intratelencephalic projecting glutamaterg...
# 2     L2/3 intratelencephalic projecting glutamaterg...
# 3     L2/3 intratelencephalic projecting glutamaterg...
# 4     L2/3 intratelencephalic projecting glutamaterg...
# ...                                                 ...
# 8761  L2/3 intratelencephalic projecting glutamaterg...
# 8762  L2/3 intratelencephalic projecting glutamaterg...
# 8763  L2/3 intratelencephalic projecting glutamaterg...
# 8764   astrocyte of the cerebral cortex;microglial cell
# 8765  L2/3 intratelencephalic projecting glutamaterg...
#
#                 tissue_name uberon_tissue_id ncbi_txid  \
# 0     middle temporal gyrus   UBERON:0002771      9606
# 1     middle temporal gyrus   UBERON:0002771      9606
# 2     middle temporal gyrus   UBERON:0002771      9606
# 3     middle temporal gyrus   UBERON:0002771      9606
# 4     middle temporal gyrus   UBERON:0002771      9606
# ...                     ...              ...       ...
# 8761  middle temporal gyrus   UBERON:0002771      9606
# 8762  middle temporal gyrus   UBERON:0002771      9606
# 8763  middle temporal gyrus   UBERON:0002771      9606
# 8764  middle temporal gyrus   UBERON:0002771      9606
# 8765  middle temporal gyrus   UBERON:0002771      9606
#
#      species_scientific_name  ensembl_gene_id
# 0                   hsapiens  ENSG00000183044
# 1                   hsapiens  ENSG00000154265
# 2                   hsapiens  ENSG00000143921
# 3                   hsapiens  ENSG00000177646
# 4                   hsapiens  ENSG00000075239
# ...                      ...              ...
# 8761                hsapiens  ENSG00000187987
# 8762                hsapiens  ENSG00000140265
# 8763                hsapiens  ENSG00000140987
# 8764                hsapiens  ENSG00000131848
# 8765                hsapiens  ENSG00000214941
#
# [8766 rows x 14 columns]

# %%
import numpy as np
import biomart as biomart

# %%
def merge_genespectra_low_spec_cl_eggnog(species_name_file:str, species_id:str, species_name: str):
    print(species_name_file)
    species_classes = pd.read_csv(f"data/1TPM_lim/{species_name_file}_classes_subclass_1TPM_ensembl_name.csv")
    species_classes_lowspec = preprocess_genespectra_output_low_spec(species_classes)

    species_classes_lowspec['tissue_name'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['tissue_name'].values[0]
    species_classes_lowspec['uberon_tissue_id'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['uberon_tissue_id'].values[0]
    species_classes_lowspec['ncbi_txid'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['ncbi_txid'].values[0]
    species_classes_lowspec['species_scientific_name'] = cell_ontology_no_ct.loc[cell_ontology_no_ct.species_scientific_name == species_name]['species_scientific_name'].values[0]


    print(species_classes_lowspec.shape)
    
    server = biomart.BiomartServer("http://www.ensembl.org/biomart")
    dataset = server.datasets[f'{species_name}_gene_ensembl']

    attributes = ['ensembl_gene_id', 'external_gene_name']
    filters = {'external_gene_name': np.unique(species_classes_lowspec['external_gene_name'].values.astype(str))}  

    print("Downloading ensembl response")

    response = dataset.search({'query': filters,
            'attributes': attributes,
            'mart_instance': 'ensembl'})

    gene_to_id = pd.read_csv(response.url, sep='\t', header=None, names=attributes)
    gene_to_id = gene_to_id.dropna()

    species_classes_final = species_classes_lowspec.merge(gene_to_id, left_on='external_gene_name', right_on='external_gene_name', how='left').dropna().reset_index(drop=True)
    print(species_classes_final.shape)

    species_classes_final.to_csv(f"data/1TPM_lim/{species_name_file}_classes_subclass_1TPM_ensembl_name_lowspec_processed_all.csv", index=False)

    
    # return species_classes_final

# %%
merge_genespectra_low_spec_cl_eggnog(species_name_file='human', species_id='9606', species_name='hsapiens')
# Out:
# human
# (9798, 13)
# Downloading ensembl response
# (9799, 14)

# %%
merge_genespectra_low_spec_cl_eggnog(species_name_file='gorilla', species_id='9593', species_name='ggorilla')
merge_genespectra_low_spec_cl_eggnog(species_name_file='chimp', species_id='9598',  species_name='ptroglodytes')
merge_genespectra_low_spec_cl_eggnog(species_name_file='macaque', species_id='9544', species_name='mmulatta')
merge_genespectra_low_spec_cl_eggnog(species_name_file='marmoset', species_id='9483', species_name='cjacchus')
# Out:
# gorilla
# (12606, 13)
# Downloading ensembl response
# (8054, 14)
# chimp
# (11372, 13)
# Downloading ensembl response
# (8084, 14)
# macaque
# (12224, 13)
# Downloading ensembl response
# (8848, 14)
# marmoset
# (12868, 13)
# Downloading ensembl response
# (8092, 14)
