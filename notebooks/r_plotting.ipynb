# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.1 --
#
# v ggplot2 3.3.6     v purrr   0.3.4
# v tibble  3.1.7     v dplyr   1.0.9
# v tidyr   1.2.0     v stringr 1.4.0
# v readr   2.1.2     v forcats 0.5.1
#
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
df = read.csv("sum_enhanced_enriched.csv")

# %%
head(df)
# Out:
#   X sp1      sp1_total_enriched sp2     num_enriched_share_og_sp1
# 1 0 marmoset  28                chimp     6
# 2 1 macaque  206                chimp    47
# 3 2 human    301                chimp    78
# 4 3 gorilla   99                chimp    31
# 5 4 marmoset  28                macaque   8
# 6 5 human    301                macaque 101
#   num_enriched_share_og_sp2 sp2_total_enriched sp1_pct   sp2_pct    hmean_pct
# 1   6                       146                0.2142857 0.04109589 0.06896552
# 2  46                       146                0.2281553 0.31506849 0.26465908
# 3  78                       146                0.2591362 0.53424658 0.34899329
# 4  32                       146                0.3131313 0.21917808 0.25786327
# 5   9                       206                0.2857143 0.04368932 0.07578947
# 6 100                       206                0.3355482 0.48543689 0.39680981
#   cell_type                        specifcity_category
# ...

# %%
dim(df)
# Out:
# [1] 706  12

# %%
df  %>% filter(specifcity_category == 'gene enriched in cell type')  %>% 
select(sp1, sp1_total_enriched, cell_type)  %>% unique()  %>%
ggplot(aes(x = cell_type, y = sp1_total_enriched)) +
geom_boxplot() + geom_jitter()
# Out:
# plot without title
